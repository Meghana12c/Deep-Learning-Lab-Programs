# %% [markdown]
# <a href="https://colab.research.google.com/github/Meghana12c/Deep-Learning-Lab-Programs/blob/main/DL_Lab_programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Addition of Matrices

# %%
def create_matrix(rows, cols):
    matrix = []
    print(f"Enter the elements of the {rows}x{cols} matrix:")
    for i in range(rows):
        row = list(map(int, input(f"Row {i + 1}: ").split()))
        if len(row) != cols:
            print(f"Please enter exactly {cols} numbers.")
            return create_matrix(rows, cols)
        matrix.append(row)
    return matrix

def add_matrices(matrix1, matrix2):
    return [[matrix1[i][j] + matrix2[i][j] for j in range(len(matrix1[0]))] for i in range(len(matrix1))]

def main():
    rows = int(input("Enter number of rows: "))
    cols = int(input("Enter number of columns: "))

    print("Matrix 1:")
    matrix1 = create_matrix(rows, cols)

    print("Matrix 2:")
    matrix2 = create_matrix(rows, cols)

    result_matrix = add_matrices(matrix1, matrix2)

    print("\nMatrix 1:")
    for row in matrix1:
        print(row)

    print("\nMatrix 2:")
    for row in matrix2:
        print(row)

    print("\nResultant Matrix after Addition:")
    for row in result_matrix:
        print(row)

if __name__ == "__main__":
    main()
# Out:
# Enter number of rows: 3
# Enter number of columns: 3
# Matrix 1:
# Enter the elements of the 3x3 matrix:
# Row 1: 1 2 3
# Row 2: 5 6 7
# Row 3: 3 7 9
# Matrix 2:
# Enter the elements of the 3x3 matrix:
# Row 1: 1 4 3
# Row 2: 5 6 9
# Row 3: 3 4 9
#
# Matrix 1:
# [1, 2, 3]
# [5, 6, 7]
# [3, 7, 9]
#
# Matrix 2:
# [1, 4, 3]
# [5, 6, 9]
# [3, 4, 9]
#
# Resultant Matrix after Addition:
# [2, 6, 6]
# [10, 12, 16]
# [6, 11, 18]

# %% [markdown]
# Multiplication of Matrices

# %%
import numpy as np

def create_random_matrix(n):
    return np.random.randint(1, 10, (n, n))

def matrix_multiplication(matrix_a, matrix_b):
    return np.dot(matrix_a, matrix_b)

def main():
    n = int(input("Enter the size of the matrices (n): "))


    matrix_a = create_random_matrix(n)
    matrix_b = create_random_matrix(n)

    print("Matrix A:")
    print(matrix_a)

    print("\nMatrix B:")
    print(matrix_b)


    result = matrix_multiplication(matrix_a, matrix_b)

    print("\nResult of A x B:")
    print(result)

if __name__ == "__main__":
    main()
# Out:
# Enter the size of the matrices (n): 2
# Matrix A:
# [[7 8]
#  [8 7]]
#
# Matrix B:
# [[4 4]
#  [5 1]]
#
# Result of A x B:
# [[68 36]
#  [67 39]]

# %% [markdown]
# Subtraction of Matrices

# %%
def matrix_subtraction():

    rows = int(input("Enter the number of rows: "))
    cols = int(input("Enter the number of columns: "))
    matrix1 = []
    matrix2 = []
    print("Enter elements of the first matrix:")
    for i in range(rows):
        row = []
        for j in range(cols):
            element = float(input(f"Enter element [{i+1}][{j+1}]: "))
            row.append(element)
        matrix1.append(row)
    print("Enter elements of the second matrix:")
    for i in range(rows):
        row = []
        for j in range(cols):
            element = float(input(f"Enter element [{i+1}][{j+1}]: "))
            row.append(element)
        matrix2.append(row)
    result_matrix = []
    for i in range(rows):
        row = []
        for j in range(cols):
            element = matrix1[i][j] - matrix2[i][j]
            row.append(element)
        result_matrix.append(row)
    print("\nResultant matrix (Matrix1 - Matrix2):")
    for row in result_matrix:
        print(row)
matrix_subtraction()
# Out:
# Enter the number of rows: 3
# Enter the number of columns: 3
# Enter elements of the first matrix:
# Enter element [1][1]: 3
# Enter element [1][2]: 4
# Enter element [1][3]: 2
# Enter element [2][1]: 5
# Enter element [2][2]: 2
# Enter element [2][3]: 7
# Enter element [3][1]: 9
# Enter element [3][2]: 1
# Enter element [3][3]: 0
# Enter elements of the second matrix:
# Enter element [1][1]: 4
# Enter element [1][2]: 6
# Enter element [1][3]: 2
# Enter element [2][1]: 8
# Enter element [2][2]: 0
# Enter element [2][3]: 7
# Enter element [3][1]: 3
# Enter element [3][2]: 2
# Enter element [3][3]: 1
#
# Resultant matrix (Matrix1 - Matrix2):
# [-1.0, -2.0, 0.0]
# [-3.0, 2.0, 0.0]
# [6.0, -1.0, -1.0]

# %% [markdown]
# Division of Matrices

# %%
def matrix_division():1
    rows = int(input("Enter the number of rows: "))
    cols = int(input("Enter the number of columns: "))
    matrix1 = []
    matrix2 = []
    print("Enter elements of the first matrix:")
    for i in range(rows):
        row = []
        for j in range(cols):
            element = float(input(f"Enter element [{i+1}][{j+1}]: "))
            row.append(element)
        matrix1.append(row)
    print("Enter elements of the second matrix:")
    for i in range(rows):
        row = []
        for j in range(cols):
            element = float(input(f"Enter element [{i+1}][{j+1}]: "))
            row.append(element)
        matrix2.append(row)
    result_matrix = []
    for i in range(rows):
        row = []
        for j in range(cols):
            if matrix2[i][j] != 0:
                element = matrix1[i][j] / matrix2[i][j]
            else:
                print("Error: Division by zero encountered.")
                return
            row.append(element)
        result_matrix.append(row)
    print("\nResultant matrix (Matrix1 / Matrix2):")
    for row in result_matrix:
        print(row)
matrix_division()
# Out:
# Enter the number of rows: 2
# Enter the number of columns: 2
# Enter elements of the first matrix:
# Enter element [1][1]: 2
# Enter element [1][2]: 4
# Enter element [2][1]: 6
# Enter element [2][2]: 2
# Enter elements of the second matrix:
# Enter element [1][1]: 5
# Enter element [1][2]: 6
# Enter element [2][1]: 3
# Enter element [2][2]: 1
#
# Resultant matrix (Matrix1 / Matrix2):
# [0.4, 0.6666666666666666]
# [2.0, 2.0]

# %% [markdown]
# Transpose of Matrices

# %%
import numpy as np
def transpose_matrix(matrix):
    return np.transpose(matrix)
n = int(input("Enter the size of the matrix (n x n): "))
matrix = []

print("Enter the elements of the matrix row by row:")
for i in range(n):
    row = list(map(float, input(f"Row {i+1}: ").split()))
    matrix.append(row)
matrix = np.array(matrix)
transposed = transpose_matrix(matrix)
print("Transposed matrix:")
print(transposed)
# Out:
# Enter the size of the matrix (n x n): 3
# Enter the elements of the matrix row by row:
# Row 1: 2
# Row 2: 4
# Row 3: 7
# Transposed matrix:
# [[2. 4. 7.]]

# %% [markdown]
# Week 2 lab

# %% [markdown]
# Matrix multiplication using keras

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dot
matrix1 = np.array([[1, 2], [3, 4]])
matrix2 = np.array([[5, 6], [7, 8]])
input1 = Input(shape=(2,))
input2 = Input(shape=(2,))
output = Dot(axes=1)([input1, input2])
model = Model(inputs=[input1, input2], outputs=output)
model.compile(optimizer='adam', loss='mean_squared_error')
result = model.predict([matrix1, matrix2])
print("Result of matrix multiplication:")
print(result)
# !pip install tensorflow
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dot
matrix1 = np.array([[1, 2], [3, 4]])
matrix2 = np.array([[5, 6], [7, 8]])
input1 = Input(shape=(2,))
input2 = Input(shape=(2,))
output = Dot(axes=1)([input1, input2])
model = Model(inputs=[input1, input2], outputs=output)
model.compile(optimizer='adam', loss='mean_squared_error')
result = model.predict([matrix1, matrix2])
print("Result of matrix multiplication:")
print(result)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Result of matrix multiplication:
# [[17.]
#  [53.]]
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Result of matrix multiplication:
# [[17.]
#  [53.]]

# %% [markdown]
# Prime numbers using keras

# %%
# !pip install tensorflow

# Import necessary libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Function to check if a number is prime
def is_prime(n):
    if n <= 1:
        return 0
    for i in range(2, int(np.sqrt(n)) + 1):
        if n % i == 0:
            return 0
    return 1

# Generate data
X = np.arange(1, 101)
y = np.array([is_prime(x) for x in X])

# Create the Keras model
model = Sequential([
    Dense(64, activation='relu', input_shape=(1,)),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X, y, epochs=5, batch_size=10)

# Function to check if a number is prime using the trained model
def check_prime(number):
    prediction = model.predict(np.array([number]))
    return prediction[0][0] > 0.5

# Get user input
user_input = int(input("Enter a number to check if it's prime: "))
if check_prime(user_input):
    print(f"{user_input} is a prime number.")
else:
    print(f"{user_input} is not a prime number.")
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Epoch 1/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6165 - loss: 0.6751
# Epoch 2/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7000 - loss: 0.7128
# Epoch 3/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7322 - loss: 0.6459
# Epoch 4/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7996 - loss: 0.5476
# Epoch 5/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6992 - loss: 0.6181
# Enter a number to check if it's prime: 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 6 is not a prime number.

# %% [markdown]
# Recurrent neural network
# 6a)Numpy impementation of simple recurrent neural network

# %%
import numpy as np

# Input size (number of features)
input_size = 3
# Hidden state size (number of hidden units)
hidden_size = 5
# Output size (number of output units)
output_size = 2

# Weight matrices
Wx = np.random.randn(hidden_size, input_size)  # Weights for the input
Wh = np.random.randn(hidden_size, hidden_size) # Weights for the hidden state
Wy = np.random.randn(output_size, hidden_size) # Weights for the output

# Bias terms
bh = np.zeros((hidden_size, 1))  # Bias for the hidden state
by = np.zeros((output_size, 1))  # Bias for the output
def rnn_step_forward(x_t, h_prev, Wx, Wh, Wy, bh, by):
    """
    Perform one time step of the RNN.

    Arguments:
    x_t -- Input data at time step t, shape (input_size, 1)
    h_prev -- Previous hidden state, shape (hidden_size, 1)

    Returns:
    h_t -- Current hidden state, shape (hidden_size, 1)
    y_t -- Output at time step t, shape (output_size, 1)
    """
    # Compute the next hidden state
    h_t = np.tanh(np.dot(Wx, x_t) + np.dot(Wh, h_prev) + bh)

    # Compute the output
    y_t = np.dot(Wy, h_t) + by

    return h_t, y_t
def rnn_forward(X, h0, Wx, Wh, Wy, bh, by):
    """
    Perform the forward pass for an entire sequence.

    Arguments:
    X -- Input data for the sequence, shape (sequence_length, input_size)
    h0 -- Initial hidden state, shape (hidden_size, 1)

    Returns:
    H -- Hidden states for all time steps, shape (sequence_length, hidden_size)
    Y -- Outputs for all time steps, shape (sequence_length, output_size)
    """
    sequence_length = X.shape[0]
    h_t = h0
    H = []
    Y = []

    for t in range(sequence_length):
        x_t = X[t].reshape(-1, 1)
        h_t, y_t = rnn_step_forward(x_t, h_t, Wx, Wh, Wy, bh, by)
        H.append(h_t)
        Y.append(y_t)

    H = np.concatenate(H, axis=1).T  # Hidden states over time
    Y = np.concatenate(Y, axis=1).T  # Outputs over time

    return H, Y
 # Example input sequence (3 time steps, input_size=3)
X = np.random.randn(3, input_size)

# Initial hidden state
h0 = np.zeros((hidden_size, 1))

# Forward pass through the RNN
H, Y = rnn_forward(X, h0, Wx, Wh, Wy, bh, by)

print("Hidden States (H):\n", H)
print("Outputs (Y):\n", Y)
# Out:
# Hidden States (H):
#  [[-0.99786402  0.51360653 -0.73719629 -0.34515075  0.99456786]
#  [-0.99881895  0.99352305  0.94706239 -0.7175457   0.99986749]
#  [-0.99197405  0.95538153  0.99681226  0.96148285 -0.94314856]]
# Outputs (Y):
#  [[-1.88173709 -2.39639354]
#  [ 1.0667965  -1.80800727]
#  [ 1.18075141 -0.04689517]]

# %% [markdown]
# 6b)create recurrent layer in keras

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Initialize the model
model = Sequential()

# Add an LSTM layer
model.add(LSTM(units=50, input_shape=(10, 1)))

# Add a Dense layer for the output
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Summary of the model
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 50)                  │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,451 (40.82 KB)
#  Trainable params: 10,451 (40.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 6c)prepare imbd data for movie review classification problem

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
vocab_size = 10000
maxlen = 200

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)
X_train = pad_sequences(X_train, maxlen=maxlen)
X_test = pad_sequences(X_test, maxlen=maxlen)
word_index = imdb.get_word_index()
reverse_word_index = {value: key for (key, value) in word_index.items()}
def decode_review(encoded_review):
    return ' '.join([reverse_word_index.get(i - 3, '?') for i in encoded_review])
print(decode_review(X_train[0]))
print("Label:", y_train[0])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# and you could just imagine being there robert ? is an amazing actor and now the same being director ? father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for ? and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also ? to the two little boy's that played the ? of norman and paul they were just brilliant children are often left out of the ? list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all
# Label: 1

# %% [markdown]
# 6d)Recurrent neurl networks D.train the model with embedding and simple RNN layers

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.datasets import imdb
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=10000)
max_len = 100
X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)
model = Sequential()
model.add(Embedding(input_dim=10000, output_dim=32, input_length=max_len))
model.add(SimpleRNN(units=50))
model.add(Dense(units=1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
model.fit(X_train, y_train, epochs=5, batch_size=32, validation_data=(X_test, y_test))
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn (SimpleRNN)               │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 30ms/step - accuracy: 0.5487 - loss: 0.6784 - val_accuracy: 0.7350 - val_loss: 0.5219
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 24s 31ms/step - accuracy: 0.8288 - loss: 0.3993 - val_accuracy: 0.8069 - val_loss: 0.4563
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - accuracy: 0.9102 - loss: 0.2279 - val_accuracy: 0.7973 - val_loss: 0.5250
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 30ms/step - accuracy: 0.9657 - loss: 0.1022 - val_accuracy: 0.7672 - val_loss: 0.6796
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 23s 30ms/step - accuracy: 0.9835 - loss: 0.0530 - val_accuracy: 0.7008 - val_loss: 1.0088
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.6985 - loss: 1.0317
# Test Accuracy: 0.7008

# %% [markdown]
# 6e)Recurrent neural networks e.plot the result

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=32, input_length=maxlen),
    SimpleRNN(32),
    Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=10, batch_size=64, validation_data=(X_test, y_test))
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper right')

plt.show()
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
import matplotlib.pyplot as plt
vocab_size = 10000
maxlen = 200
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)
X_train = pad_sequences(X_train, maxlen=maxlen)
X_test = pad_sequences(X_test, maxlen=maxlen)
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=32, input_length=maxlen),
    SimpleRNN(32),
    Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=10, batch_size=64, validation_data=(X_test, y_test))
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper right')

plt.show()
# Out:
# Epoch 1/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.6408 - loss: 0.6145 - val_accuracy: 0.8249 - val_loss: 0.4003
# Epoch 2/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.8594 - loss: 0.3394 - val_accuracy: 0.8346 - val_loss: 0.3784
# Epoch 3/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.9147 - loss: 0.2313 - val_accuracy: 0.8274 - val_loss: 0.4146
# Epoch 4/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 31ms/step - accuracy: 0.9431 - loss: 0.1589 - val_accuracy: 0.8226 - val_loss: 0.4958
# Epoch 5/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.9778 - loss: 0.0766 - val_accuracy: 0.8024 - val_loss: 0.5668
# Epoch 6/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 19s 28ms/step - accuracy: 0.9868 - loss: 0.0466 - val_accuracy: 0.7909 - val_loss: 0.6890
# Epoch 7/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.9947 - loss: 0.0230 - val_accuracy: 0.8024 - val_loss: 0.7426
# Epoch 8/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.9933 - loss: 0.0235 - val_accuracy: 0.8104 - val_loss: 0.8096
# Epoch 9/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.9943 - loss: 0.0216 - val_accuracy: 0.8072 - val_loss: 0.8637
# Epoch 10/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.9978 - loss: 0.0096 - val_accuracy: 0.7766 - val_loss: 0.9224
# Epoch 1/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 60ms/step - accuracy: 0.6262 - loss: 0.6353 - val_accuracy: 0.8240 - val_loss: 0.4109
# Epoch 2/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 54ms/step - accuracy: 0.8303 - loss: 0.3916 - val_accuracy: 0.8373 - val_loss: 0.3855
# Epoch 3/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.9080 - loss: 0.2427 - val_accuracy: 0.8496 - val_loss: 0.3777
# Epoch 4/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 40s 56ms/step - accuracy: 0.9569 - loss: 0.1266 - val_accuracy: 0.8496 - val_loss: 0.4311
# Epoch 5/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 55ms/step - accuracy: 0.9832 - loss: 0.0606 - val_accuracy: 0.8136 - val_loss: 0.5479
# Epoch 6/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 59ms/step - accuracy: 0.9927 - loss: 0.0302 - val_accuracy: 0.8139 - val_loss: 0.6223
# Epoch 7/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 59ms/step - accuracy: 0.9970 - loss: 0.0146 - val_accuracy: 0.8008 - val_loss: 0.6907
# Epoch 8/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 40s 57ms/step - accuracy: 0.9867 - loss: 0.0391 - val_accuracy: 0.8219 - val_loss: 0.6985
# Epoch 9/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 40s 55ms/step - accuracy: 0.9931 - loss: 0.0215 - val_accuracy: 0.7818 - val_loss: 0.8136
# Epoch 10/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 59ms/step - accuracy: 0.9977 - loss: 0.0089 - val_accuracy: 0.7963 - val_loss: 0.8672

# %% [markdown]
# Image Classifier Mnist dataset

# %%
# Import necessary libraries
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# Load and preprocess the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the pixel values to be between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0

# Convert labels to one-hot encoded format
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Build the model
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=100, batch_size=32,
                    validation_data=(x_test, y_test))

# Plot accuracy and loss graphs
plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - accuracy: 0.8757 - loss: 0.4237 - val_accuracy: 0.9598 - val_loss: 0.1257
# Epoch 2/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - accuracy: 0.9675 - loss: 0.1055 - val_accuracy: 0.9684 - val_loss: 0.1004
# Epoch 3/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9782 - loss: 0.0703 - val_accuracy: 0.9756 - val_loss: 0.0817
# Epoch 4/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9836 - loss: 0.0525 - val_accuracy: 0.9774 - val_loss: 0.0764
# Epoch 5/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9870 - loss: 0.0391 - val_accuracy: 0.9752 - val_loss: 0.0877
# Epoch 6/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9902 - loss: 0.0297 - val_accuracy: 0.9762 - val_loss: 0.0879
# Epoch 7/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9913 - loss: 0.0264 - val_accuracy: 0.9794 - val_loss: 0.0771
# Epoch 8/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9925 - loss: 0.0214 - val_accuracy: 0.9751 - val_loss: 0.0928
# Epoch 9/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9934 - loss: 0.0202 - val_accuracy: 0.9792 - val_loss: 0.0860
# Epoch 10/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9947 - loss: 0.0153 - val_accuracy: 0.9801 - val_loss: 0.0897
# Epoch 11/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9946 - loss: 0.0166 - val_accuracy: 0.9802 - val_loss: 0.0913
# Epoch 12/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9959 - loss: 0.0121 - val_accuracy: 0.9792 - val_loss: 0.0930
# Epoch 13/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9964 - loss: 0.0110 - val_accuracy: 0.9762 - val_loss: 0.1034
# Epoch 14/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9962 - loss: 0.0115 - val_accuracy: 0.9778 - val_loss: 0.1099
# Epoch 15/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9968 - loss: 0.0105 - val_accuracy: 0.9817 - val_loss: 0.0935
# Epoch 16/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9972 - loss: 0.0075 - val_accuracy: 0.9783 - val_loss: 0.1128
# Epoch 17/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9975 - loss: 0.0078 - val_accuracy: 0.9788 - val_loss: 0.1196
# Epoch 18/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9968 - loss: 0.0091 - val_accuracy: 0.9804 - val_loss: 0.1122
# Epoch 19/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9969 - loss: 0.0094 - val_accuracy: 0.9802 - val_loss: 0.1034
# Epoch 20/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9974 - loss: 0.0071 - val_accuracy: 0.9794 - val_loss: 0.1255
# Epoch 21/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9973 - loss: 0.0085 - val_accuracy: 0.9774 - val_loss: 0.1282
# Epoch 22/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9978 - loss: 0.0077 - val_accuracy: 0.9804 - val_loss: 0.1169
# Epoch 23/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9983 - loss: 0.0050 - val_accuracy: 0.9791 - val_loss: 0.1269
# Epoch 24/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9982 - loss: 0.0059 - val_accuracy: 0.9813 - val_loss: 0.1149
# Epoch 25/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9980 - loss: 0.0061 - val_accuracy: 0.9770 - val_loss: 0.1474
# Epoch 26/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9970 - loss: 0.0077 - val_accuracy: 0.9787 - val_loss: 0.1436
# Epoch 27/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9975 - loss: 0.0081 - val_accuracy: 0.9791 - val_loss: 0.1308
# Epoch 28/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9970 - loss: 0.0099 - val_accuracy: 0.9800 - val_loss: 0.1416
# Epoch 29/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9982 - loss: 0.0054 - val_accuracy: 0.9785 - val_loss: 0.1495
# Epoch 30/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9977 - loss: 0.0074 - val_accuracy: 0.9795 - val_loss: 0.1356
# Epoch 31/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9974 - loss: 0.0074 - val_accuracy: 0.9813 - val_loss: 0.1354
# Epoch 32/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9975 - loss: 0.0080 - val_accuracy: 0.9777 - val_loss: 0.1486
# Epoch 33/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9982 - loss: 0.0054 - val_accuracy: 0.9805 - val_loss: 0.1387
# Epoch 34/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9979 - loss: 0.0067 - val_accuracy: 0.9805 - val_loss: 0.1459
# Epoch 35/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9980 - loss: 0.0066 - val_accuracy: 0.9814 - val_loss: 0.1461
# Epoch 36/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9979 - loss: 0.0065 - val_accuracy: 0.9809 - val_loss: 0.1529
# Epoch 37/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9988 - loss: 0.0044 - val_accuracy: 0.9785 - val_loss: 0.1596
# Epoch 38/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9980 - loss: 0.0067 - val_accuracy: 0.9816 - val_loss: 0.1439
# Epoch 39/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9985 - loss: 0.0057 - val_accuracy: 0.9813 - val_loss: 0.1501
# Epoch 40/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9984 - loss: 0.0052 - val_accuracy: 0.9794 - val_loss: 0.1708
# Epoch 41/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9983 - loss: 0.0055 - val_accuracy: 0.9791 - val_loss: 0.1746
# Epoch 42/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9982 - loss: 0.0057 - val_accuracy: 0.9793 - val_loss: 0.1793
# Epoch 43/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9992 - loss: 0.0025 - val_accuracy: 0.9791 - val_loss: 0.1880
# Epoch 44/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9977 - loss: 0.0085 - val_accuracy: 0.9818 - val_loss: 0.1644
# Epoch 45/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9981 - loss: 0.0072 - val_accuracy: 0.9798 - val_loss: 0.1894
# Epoch 46/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9985 - loss: 0.0063 - val_accuracy: 0.9794 - val_loss: 0.1896
# Epoch 47/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9984 - loss: 0.0058 - val_accuracy: 0.9796 - val_loss: 0.2038
# Epoch 48/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9982 - loss: 0.0064 - val_accuracy: 0.9803 - val_loss: 0.1751
# Epoch 49/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9983 - loss: 0.0060 - val_accuracy: 0.9794 - val_loss: 0.1973
# Epoch 50/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9982 - loss: 0.0070 - val_accuracy: 0.9800 - val_loss: 0.1833
# Epoch 51/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9990 - loss: 0.0036 - val_accuracy: 0.9794 - val_loss: 0.2000
# Epoch 52/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9978 - loss: 0.0089 - val_accuracy: 0.9786 - val_loss: 0.2081
# Epoch 53/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9989 - loss: 0.0040 - val_accuracy: 0.9771 - val_loss: 0.2260
# Epoch 54/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9980 - loss: 0.0084 - val_accuracy: 0.9792 - val_loss: 0.1843
# Epoch 55/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9986 - loss: 0.0067 - val_accuracy: 0.9799 - val_loss: 0.2143
# Epoch 56/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9986 - loss: 0.0046 - val_accuracy: 0.9778 - val_loss: 0.2262
# Epoch 57/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9979 - loss: 0.0102 - val_accuracy: 0.9797 - val_loss: 0.2176
# Epoch 58/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9992 - loss: 0.0030 - val_accuracy: 0.9800 - val_loss: 0.2148
# Epoch 59/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9985 - loss: 0.0047 - val_accuracy: 0.9793 - val_loss: 0.2267
# Epoch 60/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9987 - loss: 0.0040 - val_accuracy: 0.9777 - val_loss: 0.2601
# Epoch 61/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9985 - loss: 0.0052 - val_accuracy: 0.9780 - val_loss: 0.2513
# Epoch 62/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9983 - loss: 0.0066 - val_accuracy: 0.9808 - val_loss: 0.2315
# Epoch 63/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9988 - loss: 0.0049 - val_accuracy: 0.9812 - val_loss: 0.2217
# Epoch 64/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9993 - loss: 0.0028 - val_accuracy: 0.9776 - val_loss: 0.2500
# Epoch 65/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9979 - loss: 0.0068 - val_accuracy: 0.9807 - val_loss: 0.2208
# Epoch 66/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9991 - loss: 0.0028 - val_accuracy: 0.9767 - val_loss: 0.2626
# Epoch 67/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9983 - loss: 0.0068 - val_accuracy: 0.9821 - val_loss: 0.2058
# Epoch 68/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9996 - loss: 0.0016 - val_accuracy: 0.9806 - val_loss: 0.2166
# Epoch 69/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9982 - loss: 0.0057 - val_accuracy: 0.9806 - val_loss: 0.2256
# Epoch 70/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9990 - loss: 0.0049 - val_accuracy: 0.9793 - val_loss: 0.2232
# Epoch 71/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9989 - loss: 0.0043 - val_accuracy: 0.9808 - val_loss: 0.2352
# Epoch 72/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9987 - loss: 0.0061 - val_accuracy: 0.9801 - val_loss: 0.2669
# Epoch 73/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9990 - loss: 0.0037 - val_accuracy: 0.9797 - val_loss: 0.2734
# Epoch 74/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9985 - loss: 0.0068 - val_accuracy: 0.9805 - val_loss: 0.2553
# Epoch 75/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9993 - loss: 0.0019 - val_accuracy: 0.9789 - val_loss: 0.2684
# Epoch 76/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9992 - loss: 0.0027 - val_accuracy: 0.9794 - val_loss: 0.2591
# Epoch 77/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9991 - loss: 0.0038 - val_accuracy: 0.9787 - val_loss: 0.2677
# Epoch 78/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9982 - loss: 0.0069 - val_accuracy: 0.9794 - val_loss: 0.2518
# Epoch 79/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9997 - loss: 0.0016 - val_accuracy: 0.9741 - val_loss: 0.3263
# Epoch 80/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9984 - loss: 0.0072 - val_accuracy: 0.9796 - val_loss: 0.2491
# Epoch 81/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9988 - loss: 0.0055 - val_accuracy: 0.9793 - val_loss: 0.2624
# Epoch 82/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9990 - loss: 0.0037 - val_accuracy: 0.9772 - val_loss: 0.2984
# Epoch 83/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9985 - loss: 0.0063 - val_accuracy: 0.9799 - val_loss: 0.2732
# Epoch 84/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9990 - loss: 0.0044 - val_accuracy: 0.9792 - val_loss: 0.2802
# Epoch 85/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9985 - loss: 0.0077 - val_accuracy: 0.9811 - val_loss: 0.2512
# Epoch 86/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9994 - loss: 0.0026 - val_accuracy: 0.9776 - val_loss: 0.3104
# Epoch 87/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9987 - loss: 0.0058 - val_accuracy: 0.9819 - val_loss: 0.2760
# Epoch 88/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9986 - loss: 0.0070 - val_accuracy: 0.9799 - val_loss: 0.2707
# Epoch 89/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9989 - loss: 0.0039 - val_accuracy: 0.9812 - val_loss: 0.2537
# Epoch 90/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9986 - loss: 0.0064 - val_accuracy: 0.9825 - val_loss: 0.2474
# Epoch 91/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9994 - loss: 0.0033 - val_accuracy: 0.9803 - val_loss: 0.2608
# Epoch 92/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9994 - loss: 0.0029 - val_accuracy: 0.9824 - val_loss: 0.2711
# Epoch 93/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9989 - loss: 0.0052 - val_accuracy: 0.9818 - val_loss: 0.2678
# Epoch 94/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9989 - loss: 0.0043 - val_accuracy: 0.9810 - val_loss: 0.2869
# Epoch 95/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9994 - loss: 0.0024 - val_accuracy: 0.9799 - val_loss: 0.2688
# Epoch 96/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 8ms/step - accuracy: 0.9981 - loss: 0.0101 - val_accuracy: 0.9804 - val_loss: 0.2792
# Epoch 97/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.9995 - loss: 0.0021 - val_accuracy: 0.9802 - val_loss: 0.3133
# Epoch 98/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9992 - loss: 0.0047 - val_accuracy: 0.9797 - val_loss: 0.3334
# Epoch 99/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9988 - loss: 0.0051 - val_accuracy: 0.9788 - val_loss: 0.3164
# Epoch 100/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9987 - loss: 0.0051 - val_accuracy: 0.9795 - val_loss: 0.3125

# %% [markdown]
# 7)Temperature-Forecasta)inspect the data of the weather dataset.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# Create a synthetic dataset
np.random.seed(0)
date_range = pd.date_range(start='2023-01-01', end='2023-12-31', freq='D')
temperature = 20 + 10 * np.sin(np.linspace(0, 2 * np.pi, len(date_range))) + np.random.normal(scale=2, size=len(date_range))

# Create a DataFrame
df = pd.DataFrame({'date': date_range, 'temperature': temperature})

# Convert the date column to datetime format
df['date'] = pd.to_datetime(df['date'])

# Set the date column as the index
df.set_index('date', inplace=True)

# Sort the data by date
df.sort_index(inplace=True)

# Display the first few rows of the dataset
print(df.head())
# Out:
#             temperature
# date
# 2023-01-01    23.528105
# 2023-01-02    20.972921
# 2023-01-03    22.302637
# 2023-01-04    24.999400
# 2023-01-05    24.425027

# %% [markdown]
# 7)b)parsing the data

# %%
# Display basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2023-01-01 to 2023-12-31
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   temperature  365 non-null    float64
# dtypes: float64(1)
# memory usage: 5.7 KB

# %% [markdown]
# 7)c)plotting the temperature timeseries.

# %%
# Plot the entire temperature time series
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['temperature'], label='Temperature')
plt.title('Temperature Time Series')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 7)d)plotting the first 10 days of the temperature timeseries

# %%
# Slice the DataFrame to get the first 10 days
first_10_days = df.head(10)

# Plot the temperature for the first 10 days
plt.figure(figsize=(12, 6))
plt.plot(first_10_days.index, first_10_days['temperature'], label='Temperature')
plt.title('Temperature Time Series - First 10 Days')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.legend()
plt.grid(True)
plt.show()
